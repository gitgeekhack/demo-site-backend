# %%
from scipy.stats import chi2_contingency
from scipy.stats import chi2
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('transformed_data.csv')

# %%
# df = df[['VendorPartNo', 'Sales Year', 'Make', 'Category', 'Total VIO','PartsAuthority Sales count','WorldPac Sales count', 'UnitsSold360 Sales count','Total Units Sold Sales count']]
df
# Out:
#        VendorPartNo  Sales Year           Make Category  IsDevelopment  \
# 0      000 500 0185        2016  Mercedes-Benz  Cooling          False
# 1      000 500 0185        2017  Mercedes-Benz  Cooling          False
# 2      000 500 0185        2018  Mercedes-Benz  Cooling          False
# 3      000 500 0185        2019  Mercedes-Benz  Cooling          False
# 4      000 500 0185        2020  Mercedes-Benz  Cooling          False
# ...             ...         ...            ...      ...            ...
# 23354     ZL-TO1013        2018         Toyota   Engine          False
# 23355     ZL-TO1013        2019         Toyota   Engine          False
# 23356     ZL-TO1013        2020         Toyota   Engine          False
# 23357     ZL-VS1006        2019          Volvo   Engine          False
# 23358     ZL-VS1006        2020          Volvo   Engine          False
#
#        Total VIO FirstSoldDate  vehicleMaxQty  PartsAuthority    SSF  \
# ...

# %%
x = df[['Total VIO','Total Units Sold Sales count']]
# x = x.replace(0,np.nan)
# x = x.dropna(how='all')
# x = x.fillna(0)
x
# Out:
#        Total VIO  Total Units Sold Sales count
# 0        1798416                         109.0
# 1        1798416                         225.0
# 2        1798416                         371.0
# 3        1798416                         521.0
# 4        1798416                         478.0
# ...          ...                           ...
# 23354    2345150                          11.0
# 23355    2345150                         402.0
# 23356    2345150                         239.0
# 23357      52689                           0.0
# 23358      52689                           2.0
#
# [23359 rows x 2 columns]

# %%
x.plot.scatter('Total Units Sold Sales count','Total VIO')
# Out:
# <AxesSubplot:xlabel='Total Units Sold Sales count', ylabel='Total VIO'>
