# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('transformed_data.csv')

# %%
df
# Out:
#        VendorPartNo  Sales Year           Make Category  IsDevelopment  \
# 0      000 500 0185        2016  Mercedes-Benz  Cooling              0
# 1      000 500 0185        2017  Mercedes-Benz  Cooling              0
# 2      000 500 0185        2018  Mercedes-Benz  Cooling              0
# 3      000 500 0185        2019  Mercedes-Benz  Cooling              0
# 4      000 500 0185        2020  Mercedes-Benz  Cooling              0
# ...             ...         ...            ...      ...            ...
# 23354     ZL-TO1013        2018         Toyota   Engine              0
# 23355     ZL-TO1013        2019         Toyota   Engine              0
# 23356     ZL-TO1013        2020         Toyota   Engine              0
# 23357     ZL-VS1006        2019          Volvo   Engine              0
# 23358     ZL-VS1006        2020          Volvo   Engine              0
#
#        Total VIO FirstSoldDate  vehicleMaxQty  PartsAuthority  SSF  Worldpac  \
# ...

# %%
df.columns
# Out:
# Index(['VendorPartNo', 'Sales Year', 'Make', 'Category', 'IsDevelopment',
#        'Total VIO', 'FirstSoldDate', 'vehicleMaxQty', 'PartsAuthority', 'SSF',
#        'Worldpac', 'PartsAuthority Sales count', 'SSF Sales count',
#        'WorldPac Sales count', 'UnitsSold360 Sales count',
#        'Total Units Sold Sales count', 'SalesYearRank'],
#       dtype='object')

# %%
t = df[['Sales Year', 'Make', 'Category', 'IsDevelopment', 'Total VIO',
       'vehicleMaxQty', 'PartsAuthority', 'SSF',
       'Worldpac', 'PartsAuthority Sales count', 'SSF Sales count',
       'WorldPac Sales count', 'UnitsSold360 Sales count',
       'Total Units Sold Sales count', 'SalesYearRank']].apply(lambda x: x.factorize()[0]).corr(method='pearson').round(2)
t
# Out:
#                               Sales Year  Make  Category  IsDevelopment  \
# Sales Year                          1.00  0.05      0.02           0.17
# Make                                0.05  1.00      0.02           0.11
# Category                            0.02  0.02      1.00           0.07
# IsDevelopment                       0.17  0.11      0.07           1.00
# Total VIO                           0.07  0.03      0.04           0.16
# vehicleMaxQty                       0.01  0.05      0.10           0.07
# PartsAuthority                      0.09  0.15      0.11           0.12
# SSF                                 0.00  0.06     -0.07           0.17
# Worldpac                            0.01  0.05      0.12          -0.08
# PartsAuthority Sales count          0.01 -0.06     -0.05          -0.08
# SSF Sales count                    -0.00  0.07     -0.02           0.08
# WorldPac Sales count               -0.05 -0.04     -0.09           0.03
# ...

# %%
f = plt.figure(figsize=(15, 8))
plt.matshow(t, fignum=f.number)
plt.xticks(range(t.shape[1]), t.columns, fontsize=14, rotation=90)
plt.yticks(range(t.shape[1]), t.columns, fontsize=14)
cb = plt.colorbar()
cb.ax.tick_params(labelsize=10)
plt.title('Correlation Matrix', fontsize=10)
# Out:
# Text(0.5, 1.0, 'Correlation Matrix')

# %%
t.to_csv('Correlations pearson.csv')

# %%
t = df[['Sales Year', 'Make', 'Category', 'IsDevelopment', 'Total VIO',
       'vehicleMaxQty', 'PartsAuthority', 'SSF',
       'Worldpac', 'PartsAuthority Sales count', 'SSF Sales count',
       'WorldPac Sales count', 'UnitsSold360 Sales count',
       'Total Units Sold Sales count', 'SalesYearRank']].apply(lambda x: x.factorize()[0]).corr(method='spearman').round(2)
t
# Out:
#                               Sales Year  Make  Category  IsDevelopment  \
# Sales Year                          1.00  0.04      0.02           0.17
# Make                                0.04  1.00      0.02           0.12
# Category                            0.02  0.02      1.00           0.09
# IsDevelopment                       0.17  0.12      0.09           1.00
# Total VIO                           0.07  0.03      0.07           0.19
# vehicleMaxQty                       0.01  0.08      0.29           0.09
# PartsAuthority                      0.09  0.08      0.10           0.12
# SSF                                 0.00  0.11     -0.05           0.17
# Worldpac                            0.01  0.03      0.11          -0.08
# PartsAuthority Sales count         -0.01 -0.06     -0.07          -0.13
# SSF Sales count                     0.02  0.12     -0.06           0.14
# WorldPac Sales count                0.08 -0.02     -0.15           0.05
# ...

# %%
f = plt.figure(figsize=(15, 8))
plt.matshow(t, fignum=f.number)
plt.xticks(range(t.shape[1]), t.columns, fontsize=14, rotation=90)
plt.yticks(range(t.shape[1]), t.columns, fontsize=14)
cb = plt.colorbar()
cb.ax.tick_params(labelsize=10)
plt.title('Correlation Matrix', fontsize=10)
# Out:
# Text(0.5, 1.0, 'Correlation Matrix')

# %%
t.to_csv('Correlations spearman.csv')

# %%
t = df[['Sales Year', 'Make', 'Category', 'IsDevelopment', 'Total VIO',
       'vehicleMaxQty', 'PartsAuthority', 'SSF',
       'Worldpac', 'PartsAuthority Sales count', 'SSF Sales count',
       'WorldPac Sales count', 'UnitsSold360 Sales count',
       'Total Units Sold Sales count', 'SalesYearRank']].apply(lambda x: x.factorize()[0]).corr(method='kendall').round(2)
t
# Out:
#                               Sales Year  Make  Category  IsDevelopment  \
# Sales Year                          1.00  0.03      0.02           0.15
# Make                                0.03  1.00      0.02           0.11
# Category                            0.02  0.02      1.00           0.07
# IsDevelopment                       0.15  0.11      0.07           1.00
# Total VIO                           0.05  0.02      0.05           0.15
# vehicleMaxQty                       0.01  0.06      0.24           0.09
# PartsAuthority                      0.08  0.07      0.08           0.12
# SSF                                 0.00  0.09     -0.05           0.17
# Worldpac                            0.01  0.02      0.10          -0.08
# PartsAuthority Sales count         -0.01 -0.05     -0.06          -0.12
# SSF Sales count                     0.01  0.09     -0.04           0.13
# WorldPac Sales count                0.06 -0.01     -0.12           0.04
# ...

# %%
f = plt.figure(figsize=(15, 8))
plt.matshow(t, fignum=f.number)
plt.xticks(range(t.shape[1]), t.columns, fontsize=14, rotation=90)
plt.yticks(range(t.shape[1]), t.columns, fontsize=14)
cb = plt.colorbar()
cb.ax.tick_params(labelsize=10)
plt.title('Correlation Matrix', fontsize=10)
# Out:
# Text(0.5, 1.0, 'Correlation Matrix')

# %%
t.to_csv('Correlations kendal.csv')
